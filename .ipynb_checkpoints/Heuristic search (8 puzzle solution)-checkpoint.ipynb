# %%
from queue import PriorityQueue
import numpy as np

class PuzzleNode:
    def __init__(self, state, parent=None, move=None, depth=0, cost=0):
        self.state = state
        self.parent = parent
        self.move = move
        self.depth = depth
        self.cost = cost
        self.heuristic = self.manhattan_distance()
        self.mismatch = self.mismatch_count()
        self.priority = cost + self.heuristic
    
    def __lt__(self, other):
        return self.priority < other.priority
    
    def manhattan_distance(self):
        goal = {0: (0, 0), 1: (0, 1), 2: (0, 2), 3: (1, 0), 4: (1, 1), 
                5: (1, 2), 6: (2, 0), 7: (2, 1), 8: (2, 2)}
        dist = 0
        for i in range(3):
            for j in range(3):
                val = self.state[i][j]
                if val != 0:
                    x, y = goal[val]
                    dist += abs(x - i) + abs(y - j)
        return dist
    
    def mismatch_count(self):
        goal_state = np.array([[1, 2, 3], [4, 5, 6], [7, 8, 0]])
        return np.sum(self.state != goal_state) - 1  # Exclude the blank tile
    
    def get_neighbors(self):
        neighbors = []
        x, y = np.where(self.state == 0)
        x, y = int(x), int(y)
        moves = {'Up': (x - 1, y), 'Down': (x + 1, y), 'Left': (x, y - 1), 'Right': (x, y + 1)}
        
        for move, (nx, ny) in moves.items():
            if 0 <= nx < 3 and 0 <= ny < 3:
                new_state = self.state.copy()
                new_state[x, y], new_state[nx, ny] = new_state[nx, ny], new_state[x, y]
                neighbors.append(PuzzleNode(new_state, self, move, self.depth + 1, self.depth + 1))
        
        return neighbors
    
    def path(self):
        node, path = self, []
        while node:
            path.append(node)
            node = node.parent
        return path[::-1]

def solve_puzzle(start_state):
    start_node = PuzzleNode(np.array(start_state))
    goal_state = np.array([[1, 2, 3], [4, 5, 6], [7, 8, 0]])
    frontier = PriorityQueue()
    frontier.put(start_node)
    explored = set()
    
    while not frontier.empty():
        node = frontier.get()
        
        if np.array_equal(node.state, goal_state):
            return node.path()
        
        explored.add(tuple(map(tuple, node.state)))
        
        neighbors = node.get_neighbors()
        neighbors.sort(key=lambda n: (n.mismatch, n.priority))  # Sort by lowest mismatch, then lowest cost move
        
        print(f"Choosing move with lowest mismatch at depth {node.depth}:")
        for neighbor in neighbors:
            print(f"Move: {neighbor.move},  Mismatch: {neighbor.mismatch}")
            print("State after move:")
            print(neighbor.state)
            print()
        
        if neighbors:
            chosen_neighbor = neighbors[0]
            print("Chosen move with lowest mismatch:")
            print(f"Move: {chosen_neighbor.move}, Mismatch: {chosen_neighbor.mismatch}")
            print("Chosen state:")
            print(chosen_neighbor.state)
            print()
        
        for neighbor in neighbors:
            if tuple(map(tuple, neighbor.state)) not in explored:
                frontier.put(neighbor)
    
    return None

# Example usage:
initial_state = [[1, 2, 3], [0, 4, 6], [7, 5, 8]]
solution = solve_puzzle(initial_state)

if solution:
    for step, node in enumerate(solution):
        print(f"Step {step}: Move {node.move}")
        print(f"Mismatch count: {node.mismatch}")
        print("State:")
        print(node.state)
        print()
else:
    print("No solution found.")
# Out:
# Choosing move with lowest mismatch at depth 0:
# Move: Right,  Mismatch: 2
# State after move:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Move: Up,  Mismatch: 4
# State after move:
# [[0 2 3]
#  [1 4 6]
#  [7 5 8]]
#
# Move: Down,  Mismatch: 4
# State after move:
# [[1 2 3]
#  [7 4 6]
#  [0 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 1:
# Move: Down,  Mismatch: 1
# State after move:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# Move: Left,  Mismatch: 3
# State after move:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Move: Right,  Mismatch: 3
# State after move:
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
#
# Move: Up,  Mismatch: 3
# State after move:
# [[1 0 3]
#  [4 2 6]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 1
# Chosen state:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# Choosing move with lowest mismatch at depth 1:
# Move: Down,  Mismatch: 3
# State after move:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Move: Right,  Mismatch: 5
# State after move:
# [[2 0 3]
#  [1 4 6]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 3
# Chosen state:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 2:
# Move: Right,  Mismatch: -1
# State after move:
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
#
# Move: Left,  Mismatch: 2
# State after move:
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
#
# Move: Up,  Mismatch: 2
# State after move:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: -1
# Chosen state:
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
#
# Choosing move with lowest mismatch at depth 1:
# Move: Up,  Mismatch: 3
# State after move:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Move: Right,  Mismatch: 4
# State after move:
# [[1 2 3]
#  [7 4 6]
#  [5 0 8]]
#
# Chosen move with lowest mismatch:
# Move: Up, Mismatch: 3
# Chosen state:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 3:
# Move: Right,  Mismatch: 1
# State after move:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# Move: Up,  Mismatch: 3
# State after move:
# [[1 2 3]
#  [0 5 6]
#  [4 7 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 1
# Chosen state:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# Choosing move with lowest mismatch at depth 2:
# Move: Down,  Mismatch: 2
# State after move:
# [[1 2 3]
#  [4 6 8]
#  [7 5 0]]
#
# Move: Left,  Mismatch: 2
# State after move:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Move: Up,  Mismatch: 4
# State after move:
# [[1 2 0]
#  [4 6 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [4 6 8]
#  [7 5 0]]
#
# Choosing move with lowest mismatch at depth 3:
# Move: Down,  Mismatch: 3
# State after move:
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
#
# Move: Left,  Mismatch: 5
# State after move:
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 3
# Chosen state:
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 4:
# Move: Right,  Mismatch: 4
# State after move:
# [[1 2 0]
#  [4 6 3]
#  [7 5 8]]
#
# Move: Down,  Mismatch: 5
# State after move:
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
#
# Move: Left,  Mismatch: 6
# State after move:
# [[0 1 2]
#  [4 6 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 4
# Chosen state:
# [[1 2 0]
#  [4 6 3]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 5:
# Move: Right,  Mismatch: 5
# State after move:
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
#
# Move: Down,  Mismatch: 7
# State after move:
# [[4 1 2]
#  [0 6 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 5
# Chosen state:
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 4:
# Move: Down,  Mismatch: 2
# State after move:
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
#
# Move: Up,  Mismatch: 4
# State after move:
# [[0 2 3]
#  [1 5 6]
#  [4 7 8]]
#
# Move: Right,  Mismatch: 4
# State after move:
# [[1 2 3]
#  [5 0 6]
#  [4 7 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
#
# Choosing move with lowest mismatch at depth 5:
# Move: Down,  Mismatch: 4
# State after move:
# [[1 6 2]
#  [4 5 3]
#  [7 0 8]]
#
# Move: Up,  Mismatch: 5
# State after move:
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
#
# Move: Right,  Mismatch: 5
# State after move:
# [[1 6 2]
#  [4 3 0]
#  [7 5 8]]
#
# Move: Left,  Mismatch: 6
# State after move:
# [[1 6 2]
#  [0 4 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 4
# Chosen state:
# [[1 6 2]
#  [4 5 3]
#  [7 0 8]]
#
# Choosing move with lowest mismatch at depth 2:
# Move: Left,  Mismatch: 4
# State after move:
# [[0 2 3]
#  [1 4 6]
#  [7 5 8]]
#
# Move: Down,  Mismatch: 5
# State after move:
# [[2 4 3]
#  [1 0 6]
#  [7 5 8]]
#
# Move: Right,  Mismatch: 6
# State after move:
# [[2 3 0]
#  [1 4 6]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Left, Mismatch: 4
# Chosen state:
# [[0 2 3]
#  [1 4 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 6:
# Move: Up,  Mismatch: 6
# State after move:
# [[0 1 2]
#  [4 6 3]
#  [7 5 8]]
#
# Move: Right,  Mismatch: 7
# State after move:
# [[4 1 2]
#  [6 0 3]
#  [7 5 8]]
#
# Move: Down,  Mismatch: 8
# State after move:
# [[4 1 2]
#  [7 6 3]
#  [0 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Up, Mismatch: 6
# Chosen state:
# [[0 1 2]
#  [4 6 3]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 3:
# Move: Up,  Mismatch: 3
# State after move:
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
#
# Move: Left,  Mismatch: 3
# State after move:
# [[1 2 3]
#  [4 6 8]
#  [7 0 5]]
#
# Chosen move with lowest mismatch:
# Move: Up, Mismatch: 3
# Chosen state:
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 6:
# Move: Right,  Mismatch: 5
# State after move:
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
#
# Move: Up,  Mismatch: 7
# State after move:
# [[0 6 2]
#  [1 4 3]
#  [7 5 8]]
#
# Move: Down,  Mismatch: 7
# State after move:
# [[1 6 2]
#  [7 4 3]
#  [0 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 5
# Chosen state:
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 3:
# Move: Left,  Mismatch: 5
# State after move:
# [[2 0 3]
#  [1 4 6]
#  [7 5 8]]
#
# Move: Down,  Mismatch: 7
# State after move:
# [[2 3 6]
#  [1 4 0]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Left, Mismatch: 5
# Chosen state:
# [[2 0 3]
#  [1 4 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 7:
# Move: Down,  Mismatch: 6
# State after move:
# [[4 1 2]
#  [6 5 3]
#  [7 0 8]]
#
# Move: Right,  Mismatch: 7
# State after move:
# [[4 1 2]
#  [6 3 0]
#  [7 5 8]]
#
# Move: Up,  Mismatch: 7
# State after move:
# [[4 0 2]
#  [6 1 3]
#  [7 5 8]]
#
# Move: Left,  Mismatch: 7
# State after move:
# [[4 1 2]
#  [0 6 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 6
# Chosen state:
# [[4 1 2]
#  [6 5 3]
#  [7 0 8]]
#
# Choosing move with lowest mismatch at depth 4:
# Move: Right,  Mismatch: 2
# State after move:
# [[1 2 3]
#  [4 6 8]
#  [7 5 0]]
#
# Move: Up,  Mismatch: 3
# State after move:
# [[1 2 3]
#  [4 0 8]
#  [7 6 5]]
#
# Move: Left,  Mismatch: 4
# State after move:
# [[1 2 3]
#  [4 6 8]
#  [0 7 5]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [4 6 8]
#  [7 5 0]]
#
# Choosing move with lowest mismatch at depth 8:
# Move: Right,  Mismatch: 4
# State after move:
# [[4 1 2]
#  [6 5 3]
#  [7 8 0]]
#
# Move: Left,  Mismatch: 7
# State after move:
# [[4 1 2]
#  [6 5 3]
#  [0 7 8]]
#
# Move: Up,  Mismatch: 7
# State after move:
# [[4 1 2]
#  [6 0 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 4
# Chosen state:
# [[4 1 2]
#  [6 5 3]
#  [7 8 0]]
#
# Choosing move with lowest mismatch at depth 8:
# Move: Down,  Mismatch: 6
# State after move:
# [[4 1 2]
#  [6 3 8]
#  [7 5 0]]
#
# Move: Up,  Mismatch: 7
# State after move:
# [[4 1 0]
#  [6 3 2]
#  [7 5 8]]
#
# Move: Left,  Mismatch: 7
# State after move:
# [[4 1 2]
#  [6 0 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 6
# Chosen state:
# [[4 1 2]
#  [6 3 8]
#  [7 5 0]]
#
# Choosing move with lowest mismatch at depth 5:
# Move: Right,  Mismatch: 3
# State after move:
# [[1 2 3]
#  [4 6 8]
#  [7 0 5]]
#
# Move: Up,  Mismatch: 5
# State after move:
# [[1 2 3]
#  [0 6 8]
#  [4 7 5]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 3
# Chosen state:
# [[1 2 3]
#  [4 6 8]
#  [7 0 5]]
#
# Choosing move with lowest mismatch at depth 9:
# Move: Right,  Mismatch: 6
# State after move:
# [[4 1 2]
#  [6 5 3]
#  [7 0 8]]
#
# Move: Up,  Mismatch: 7
# State after move:
# [[4 1 2]
#  [0 5 3]
#  [6 7 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 6
# Chosen state:
# [[4 1 2]
#  [6 5 3]
#  [7 0 8]]
#
# Choosing move with lowest mismatch at depth 2:
# Move: Down,  Mismatch: 2
# State after move:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Move: Left,  Mismatch: 4
# State after move:
# [[0 1 3]
#  [4 2 6]
#  [7 5 8]]
#
# Move: Right,  Mismatch: 4
# State after move:
# [[1 3 0]
#  [4 2 6]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 2:
# Move: Right,  Mismatch: 2
# State after move:
# [[1 2 3]
#  [7 4 6]
#  [5 8 0]]
#
# Move: Left,  Mismatch: 4
# State after move:
# [[1 2 3]
#  [7 4 6]
#  [0 5 8]]
#
# Move: Up,  Mismatch: 4
# State after move:
# [[1 2 3]
#  [7 0 6]
#  [5 4 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [7 4 6]
#  [5 8 0]]
#
# Choosing move with lowest mismatch at depth 6:
# Move: Down,  Mismatch: 4
# State after move:
# [[1 6 2]
#  [4 3 8]
#  [7 5 0]]
#
# Move: Up,  Mismatch: 5
# State after move:
# [[1 6 0]
#  [4 3 2]
#  [7 5 8]]
#
# Move: Left,  Mismatch: 5
# State after move:
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 4
# Chosen state:
# [[1 6 2]
#  [4 3 8]
#  [7 5 0]]
#
# Choosing move with lowest mismatch at depth 10:
# Move: Up,  Mismatch: 6
# State after move:
# [[0 1 2]
#  [4 5 3]
#  [6 7 8]]
#
# Move: Down,  Mismatch: 7
# State after move:
# [[4 1 2]
#  [6 5 3]
#  [0 7 8]]
#
# Move: Right,  Mismatch: 8
# State after move:
# [[4 1 2]
#  [5 0 3]
#  [6 7 8]]
#
# Chosen move with lowest mismatch:
# Move: Up, Mismatch: 6
# Chosen state:
# [[0 1 2]
#  [4 5 3]
#  [6 7 8]]
#
# Choosing move with lowest mismatch at depth 3:
# Move: Left,  Mismatch: 3
# State after move:
# [[1 0 3]
#  [4 2 6]
#  [7 5 8]]
#
# Move: Down,  Mismatch: 5
# State after move:
# [[1 3 6]
#  [4 2 0]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Left, Mismatch: 3
# Chosen state:
# [[1 0 3]
#  [4 2 6]
#  [7 5 8]]
#
# Step 0: Move None
# Mismatch count: 3
# State:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Step 1: Move Right
# Mismatch count: 2
# State:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Step 2: Move Down
# Mismatch count: 1
# State:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# Step 3: Move Right
# Mismatch count: -1
# State:
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
# C:\Users\mdsho\AppData\Local\Temp\ipykernel_44764\1965085759.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x, y = int(x), int(y)

# %%
# Out:
# Choosing move with lowest mismatch at depth 0:
# Move: Right, Cost: 1, Heuristic: 12, Mismatch: 2, Priority: 13
# State after move:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Move: Up, Cost: 1, Heuristic: 12, Mismatch: 4, Priority: 13
# State after move:
# [[0 2 3]
#  [1 4 6]
#  [7 5 8]]
#
# Move: Down, Cost: 1, Heuristic: 12, Mismatch: 4, Priority: 13
# State after move:
# [[1 2 3]
#  [7 4 6]
#  [0 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 1:
# Move: Down, Cost: 2, Heuristic: 11, Mismatch: 1, Priority: 13
# State after move:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# Move: Left, Cost: 2, Heuristic: 11, Mismatch: 3, Priority: 13
# State after move:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Move: Right, Cost: 2, Heuristic: 11, Mismatch: 3, Priority: 13
# State after move:
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
#
# Move: Up, Cost: 2, Heuristic: 13, Mismatch: 3, Priority: 15
# State after move:
# [[1 0 3]
#  [4 2 6]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 1
# Chosen state:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# Choosing move with lowest mismatch at depth 1:
# Move: Down, Cost: 2, Heuristic: 11, Mismatch: 3, Priority: 13
# State after move:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Move: Right, Cost: 2, Heuristic: 13, Mismatch: 5, Priority: 15
# State after move:
# [[2 0 3]
#  [1 4 6]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 3
# Chosen state:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 2:
# Move: Right, Cost: 3, Heuristic: 12, Mismatch: -1, Priority: 15
# State after move:
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
#
# Move: Left, Cost: 3, Heuristic: 10, Mismatch: 2, Priority: 13
# State after move:
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
#
# Move: Up, Cost: 3, Heuristic: 12, Mismatch: 2, Priority: 15
# State after move:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: -1
# Chosen state:
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
#
# Choosing move with lowest mismatch at depth 1:
# Move: Up, Cost: 2, Heuristic: 11, Mismatch: 3, Priority: 13
# State after move:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Move: Right, Cost: 2, Heuristic: 13, Mismatch: 4, Priority: 15
# State after move:
# [[1 2 3]
#  [7 4 6]
#  [5 0 8]]
#
# Chosen move with lowest mismatch:
# Move: Up, Mismatch: 3
# Chosen state:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 3:
# Move: Right, Cost: 4, Heuristic: 11, Mismatch: 1, Priority: 15
# State after move:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# Move: Up, Cost: 4, Heuristic: 11, Mismatch: 3, Priority: 15
# State after move:
# [[1 2 3]
#  [0 5 6]
#  [4 7 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 1
# Chosen state:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# Choosing move with lowest mismatch at depth 2:
# Move: Down, Cost: 3, Heuristic: 12, Mismatch: 2, Priority: 15
# State after move:
# [[1 2 3]
#  [4 6 8]
#  [7 5 0]]
#
# Move: Left, Cost: 3, Heuristic: 12, Mismatch: 2, Priority: 15
# State after move:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Move: Up, Cost: 3, Heuristic: 10, Mismatch: 4, Priority: 13
# State after move:
# [[1 2 0]
#  [4 6 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [4 6 8]
#  [7 5 0]]
#
# Choosing move with lowest mismatch at depth 3:
# Move: Down, Cost: 4, Heuristic: 11, Mismatch: 3, Priority: 15
# State after move:
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
#
# Move: Left, Cost: 4, Heuristic: 9, Mismatch: 5, Priority: 13
# State after move:
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 3
# Chosen state:
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 4:
# Move: Right, Cost: 5, Heuristic: 10, Mismatch: 4, Priority: 15
# State after move:
# [[1 2 0]
#  [4 6 3]
#  [7 5 8]]
#
# Move: Down, Cost: 5, Heuristic: 10, Mismatch: 5, Priority: 15
# State after move:
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
#
# Move: Left, Cost: 5, Heuristic: 8, Mismatch: 6, Priority: 13
# State after move:
# [[0 1 2]
#  [4 6 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 4
# Chosen state:
# [[1 2 0]
#  [4 6 3]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 5:
# Move: Right, Cost: 6, Heuristic: 9, Mismatch: 5, Priority: 15
# State after move:
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
#
# Move: Down, Cost: 6, Heuristic: 9, Mismatch: 7, Priority: 15
# State after move:
# [[4 1 2]
#  [0 6 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 5
# Chosen state:
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 4:
# Move: Down, Cost: 5, Heuristic: 10, Mismatch: 2, Priority: 15
# State after move:
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
#
# Move: Up, Cost: 5, Heuristic: 12, Mismatch: 4, Priority: 17
# State after move:
# [[0 2 3]
#  [1 5 6]
#  [4 7 8]]
#
# Move: Right, Cost: 5, Heuristic: 12, Mismatch: 4, Priority: 17
# State after move:
# [[1 2 3]
#  [5 0 6]
#  [4 7 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
#
# Choosing move with lowest mismatch at depth 5:
# Move: Down, Cost: 6, Heuristic: 9, Mismatch: 4, Priority: 15
# State after move:
# [[1 6 2]
#  [4 5 3]
#  [7 0 8]]
#
# Move: Up, Cost: 6, Heuristic: 9, Mismatch: 5, Priority: 15
# State after move:
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
#
# Move: Right, Cost: 6, Heuristic: 9, Mismatch: 5, Priority: 15
# State after move:
# [[1 6 2]
#  [4 3 0]
#  [7 5 8]]
#
# Move: Left, Cost: 6, Heuristic: 9, Mismatch: 6, Priority: 15
# State after move:
# [[1 6 2]
#  [0 4 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 4
# Chosen state:
# [[1 6 2]
#  [4 5 3]
#  [7 0 8]]
#
# Choosing move with lowest mismatch at depth 2:
# Move: Left, Cost: 3, Heuristic: 12, Mismatch: 4, Priority: 15
# State after move:
# [[0 2 3]
#  [1 4 6]
#  [7 5 8]]
#
# Move: Down, Cost: 3, Heuristic: 14, Mismatch: 5, Priority: 17
# State after move:
# [[2 4 3]
#  [1 0 6]
#  [7 5 8]]
#
# Move: Right, Cost: 3, Heuristic: 12, Mismatch: 6, Priority: 15
# State after move:
# [[2 3 0]
#  [1 4 6]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Left, Mismatch: 4
# Chosen state:
# [[0 2 3]
#  [1 4 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 6:
# Move: Up, Cost: 7, Heuristic: 8, Mismatch: 6, Priority: 15
# State after move:
# [[0 1 2]
#  [4 6 3]
#  [7 5 8]]
#
# Move: Right, Cost: 7, Heuristic: 8, Mismatch: 7, Priority: 15
# State after move:
# [[4 1 2]
#  [6 0 3]
#  [7 5 8]]
#
# Move: Down, Cost: 7, Heuristic: 10, Mismatch: 8, Priority: 17
# State after move:
# [[4 1 2]
#  [7 6 3]
#  [0 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Up, Mismatch: 6
# Chosen state:
# [[0 1 2]
#  [4 6 3]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 3:
# Move: Up, Cost: 4, Heuristic: 11, Mismatch: 3, Priority: 15
# State after move:
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
#
# Move: Left, Cost: 4, Heuristic: 11, Mismatch: 3, Priority: 15
# State after move:
# [[1 2 3]
#  [4 6 8]
#  [7 0 5]]
#
# Chosen move with lowest mismatch:
# Move: Up, Mismatch: 3
# Chosen state:
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 6:
# Move: Right, Cost: 7, Heuristic: 10, Mismatch: 5, Priority: 17
# State after move:
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
#
# Move: Up, Cost: 7, Heuristic: 10, Mismatch: 7, Priority: 17
# State after move:
# [[0 6 2]
#  [1 4 3]
#  [7 5 8]]
#
# Move: Down, Cost: 7, Heuristic: 10, Mismatch: 7, Priority: 17
# State after move:
# [[1 6 2]
#  [7 4 3]
#  [0 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 5
# Chosen state:
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 3:
# Move: Left, Cost: 4, Heuristic: 13, Mismatch: 5, Priority: 17
# State after move:
# [[2 0 3]
#  [1 4 6]
#  [7 5 8]]
#
# Move: Down, Cost: 4, Heuristic: 13, Mismatch: 7, Priority: 17
# State after move:
# [[2 3 6]
#  [1 4 0]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Left, Mismatch: 5
# Chosen state:
# [[2 0 3]
#  [1 4 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 7:
# Move: Down, Cost: 8, Heuristic: 7, Mismatch: 6, Priority: 15
# State after move:
# [[4 1 2]
#  [6 5 3]
#  [7 0 8]]
#
# Move: Right, Cost: 8, Heuristic: 7, Mismatch: 7, Priority: 15
# State after move:
# [[4 1 2]
#  [6 3 0]
#  [7 5 8]]
#
# Move: Up, Cost: 8, Heuristic: 9, Mismatch: 7, Priority: 17
# State after move:
# [[4 0 2]
#  [6 1 3]
#  [7 5 8]]
#
# Move: Left, Cost: 8, Heuristic: 9, Mismatch: 7, Priority: 17
# State after move:
# [[4 1 2]
#  [0 6 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 6
# Chosen state:
# [[4 1 2]
#  [6 5 3]
#  [7 0 8]]
#
# Choosing move with lowest mismatch at depth 4:
# Move: Right, Cost: 5, Heuristic: 12, Mismatch: 2, Priority: 17
# State after move:
# [[1 2 3]
#  [4 6 8]
#  [7 5 0]]
#
# Move: Up, Cost: 5, Heuristic: 10, Mismatch: 3, Priority: 15
# State after move:
# [[1 2 3]
#  [4 0 8]
#  [7 6 5]]
#
# Move: Left, Cost: 5, Heuristic: 10, Mismatch: 4, Priority: 15
# State after move:
# [[1 2 3]
#  [4 6 8]
#  [0 7 5]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [4 6 8]
#  [7 5 0]]
#
# Choosing move with lowest mismatch at depth 8:
# Move: Right, Cost: 9, Heuristic: 8, Mismatch: 4, Priority: 17
# State after move:
# [[4 1 2]
#  [6 5 3]
#  [7 8 0]]
#
# Move: Left, Cost: 9, Heuristic: 6, Mismatch: 7, Priority: 15
# State after move:
# [[4 1 2]
#  [6 5 3]
#  [0 7 8]]
#
# Move: Up, Cost: 9, Heuristic: 8, Mismatch: 7, Priority: 17
# State after move:
# [[4 1 2]
#  [6 0 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 4
# Chosen state:
# [[4 1 2]
#  [6 5 3]
#  [7 8 0]]
#
# Choosing move with lowest mismatch at depth 8:
# Move: Down, Cost: 9, Heuristic: 8, Mismatch: 6, Priority: 17
# State after move:
# [[4 1 2]
#  [6 3 8]
#  [7 5 0]]
#
# Move: Up, Cost: 9, Heuristic: 8, Mismatch: 7, Priority: 17
# State after move:
# [[4 1 0]
#  [6 3 2]
#  [7 5 8]]
#
# Move: Left, Cost: 9, Heuristic: 8, Mismatch: 7, Priority: 17
# State after move:
# [[4 1 2]
#  [6 0 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 6
# Chosen state:
# [[4 1 2]
#  [6 3 8]
#  [7 5 0]]
#
# Choosing move with lowest mismatch at depth 5:
# Move: Right, Cost: 6, Heuristic: 11, Mismatch: 3, Priority: 17
# State after move:
# [[1 2 3]
#  [4 6 8]
#  [7 0 5]]
#
# Move: Up, Cost: 6, Heuristic: 11, Mismatch: 5, Priority: 17
# State after move:
# [[1 2 3]
#  [0 6 8]
#  [4 7 5]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 3
# Chosen state:
# [[1 2 3]
#  [4 6 8]
#  [7 0 5]]
#
# Choosing move with lowest mismatch at depth 9:
# Move: Right, Cost: 10, Heuristic: 7, Mismatch: 6, Priority: 17
# State after move:
# [[4 1 2]
#  [6 5 3]
#  [7 0 8]]
#
# Move: Up, Cost: 10, Heuristic: 5, Mismatch: 7, Priority: 15
# State after move:
# [[4 1 2]
#  [0 5 3]
#  [6 7 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 6
# Chosen state:
# [[4 1 2]
#  [6 5 3]
#  [7 0 8]]
#
# Choosing move with lowest mismatch at depth 2:
# Move: Down, Cost: 3, Heuristic: 12, Mismatch: 2, Priority: 15
# State after move:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Move: Left, Cost: 3, Heuristic: 12, Mismatch: 4, Priority: 15
# State after move:
# [[0 1 3]
#  [4 2 6]
#  [7 5 8]]
#
# Move: Right, Cost: 3, Heuristic: 12, Mismatch: 4, Priority: 15
# State after move:
# [[1 3 0]
#  [4 2 6]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Choosing move with lowest mismatch at depth 2:
# Move: Right, Cost: 3, Heuristic: 14, Mismatch: 2, Priority: 17
# State after move:
# [[1 2 3]
#  [7 4 6]
#  [5 8 0]]
#
# Move: Left, Cost: 3, Heuristic: 12, Mismatch: 4, Priority: 15
# State after move:
# [[1 2 3]
#  [7 4 6]
#  [0 5 8]]
#
# Move: Up, Cost: 3, Heuristic: 14, Mismatch: 4, Priority: 17
# State after move:
# [[1 2 3]
#  [7 0 6]
#  [5 4 8]]
#
# Chosen move with lowest mismatch:
# Move: Right, Mismatch: 2
# Chosen state:
# [[1 2 3]
#  [7 4 6]
#  [5 8 0]]
#
# Choosing move with lowest mismatch at depth 6:
# Move: Down, Cost: 7, Heuristic: 10, Mismatch: 4, Priority: 17
# State after move:
# [[1 6 2]
#  [4 3 8]
#  [7 5 0]]
#
# Move: Up, Cost: 7, Heuristic: 10, Mismatch: 5, Priority: 17
# State after move:
# [[1 6 0]
#  [4 3 2]
#  [7 5 8]]
#
# Move: Left, Cost: 7, Heuristic: 10, Mismatch: 5, Priority: 17
# State after move:
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Down, Mismatch: 4
# Chosen state:
# [[1 6 2]
#  [4 3 8]
#  [7 5 0]]
#
# Choosing move with lowest mismatch at depth 10:
# Move: Up, Cost: 11, Heuristic: 4, Mismatch: 6, Priority: 15
# State after move:
# [[0 1 2]
#  [4 5 3]
#  [6 7 8]]
#
# Move: Down, Cost: 11, Heuristic: 6, Mismatch: 7, Priority: 17
# State after move:
# [[4 1 2]
#  [6 5 3]
#  [0 7 8]]
#
# Move: Right, Cost: 11, Heuristic: 6, Mismatch: 8, Priority: 17
# State after move:
# [[4 1 2]
#  [5 0 3]
#  [6 7 8]]
#
# Chosen move with lowest mismatch:
# Move: Up, Mismatch: 6
# Chosen state:
# [[0 1 2]
#  [4 5 3]
#  [6 7 8]]
#
# Choosing move with lowest mismatch at depth 3:
# Move: Left, Cost: 4, Heuristic: 13, Mismatch: 3, Priority: 17
# State after move:
# [[1 0 3]
#  [4 2 6]
#  [7 5 8]]
#
# Move: Down, Cost: 4, Heuristic: 13, Mismatch: 5, Priority: 17
# State after move:
# [[1 3 6]
#  [4 2 0]
#  [7 5 8]]
#
# Chosen move with lowest mismatch:
# Move: Left, Mismatch: 3
# Chosen state:
# [[1 0 3]
#  [4 2 6]
#  [7 5 8]]
#
# Step 0: Move None
# Cost of moving: 0
# Heuristic value: 11
# Mismatch count: 3
# State:
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
#
# Step 1: Move Right
# Cost of moving: 1
# Heuristic value: 12
# Mismatch count: 2
# State:
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# Step 2: Move Down
# Cost of moving: 2
# Heuristic value: 11
# Mismatch count: 1
# State:
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# Step 3: Move Right
# Cost of moving: 3
# Heuristic value: 12
# Mismatch count: -1
# State:
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
# C:\Users\mdsho\AppData\Local\Temp\ipykernel_44764\3811676322.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x, y = int(x), int(y)
