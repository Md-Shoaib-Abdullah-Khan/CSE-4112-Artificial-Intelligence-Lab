# %% [markdown]
#  **1. Build a fully connected neural network (FCNN) and a convolutional neural
# network (CNN) for classifying 10 classes of images.**

# %% [markdown]
# **FCNN**

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten

num_classes = 10

inputs = Input((28, 28, 1), name='InputLayer')
x = Flatten()(inputs)

x = Dense(512, activation='relu')(x)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)

outputs = Dense(num_classes, activation='softmax', name='OutputLayer')(x)

fcnn_model = Model(inputs, outputs, name='FCNN')

fcnn_model.summary()
# Out:
# Model: "FCNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ InputLayer (InputLayer)              │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 512)                 │         401,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ OutputLayer (Dense)                  │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 575,050 (2.19 MB)
#  Trainable params: 575,050 (2.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **CNN**

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense

num_classes = 10

inputs = Input((28, 28, 1), name='InputLayer')
x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
outputs = Dense(num_classes, activation='softmax', name='OutputLayer')(x)

cnn_model = Model(inputs, outputs, name='CNN')
cnn_model.summary()
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ InputLayer (InputLayer)              │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 7, 7, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 3, 3, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 1152)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ OutputLayer (Dense)                  │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 249,162 (973.29 KB)
#  Trainable params: 249,162 (973.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **2.Train and test your FCNN and CNN by the Fashion dataset. Discuss your results by comparing performance between two types of networks.**

# %% [markdown]
# **Loading Fashion Dataset and preprocessing**

# %%
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.utils import to_categorical

# Load Fashion MNIST dataset
(trainX, trainY), (testX, testY) = fashion_mnist.load_data()

# Investigate loaded data
print('trainX.shape: {}, trainY.shape: {}, testX.shape: {}, testY.shape: {}'.format(trainX.shape, trainY.shape, testX.shape, testY.shape))
print('trainX.dtype: {}, trainY.dtype: {}, testX.dtype: {}, testY.dtype: {}'.format(trainX.dtype, trainY.dtype, testX.dtype, testY.dtype))
print('trainX.Range: {} - {}, testX.Range: {} - {}'.format(trainX.max(), trainX.min(), testX.max(), testX.min()))

# Display some images
def display_img(img_set, title_set):
  n = len(title_set)
  for i in range(n):
    plt.subplot(3, 3, i + 1)
    plt.imshow(img_set[i], cmap='gray')
    plt.title(title_set[i])
  plt.show()
  plt.close()

display_img(trainX[:9], trainY[:9])

# Reshape the data to add a channel dimension (for CNN)
trainX = np.expand_dims(trainX, axis=-1)
testX = np.expand_dims(testX, axis=-1)

# Normalize the data to the range [0, 1]
trainX = trainX / 255.0
testX = testX / 255.0

# Convert labels to one-hot encoding
trainY = to_categorical(trainY, num_classes=10)
testY = to_categorical(testY, num_classes=10)

# Investigate the updated shapes
print('trainX.shape: {}, testX.shape: {}'.format(trainX.shape, testX.shape))
print('trainY.shape: {}, testY.shape: {}'.format(trainY.shape, testY.shape))
# Out:
# trainX.shape: (60000, 28, 28), trainY.shape: (60000,), testX.shape: (10000, 28, 28), testY.shape: (10000,)
# trainX.dtype: uint8, trainY.dtype: uint8, testX.dtype: uint8, testY.dtype: uint8
# trainX.Range: 255 - 0, testX.Range: 255 - 0
# trainX.shape: (60000, 28, 28, 1), testX.shape: (10000, 28, 28, 1)
# trainY.shape: (60000, 10), testY.shape: (10000, 10)

# %% [markdown]
# **Training and Testing FCNN with Fashion Dataset**

# %%
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Input, Flatten, Dense
from tensorflow.keras.models import Model

fcnn_model.compile(loss='categorical_crossentropy', optimizer=RMSprop(), metrics=['accuracy'])
fcnn_history = fcnn_model.fit(trainX, trainY, batch_size=32, validation_split=0.1, epochs=10)

fcnn_test_loss, fcnn_test_acc = fcnn_model.evaluate(testX, testY)
print(f"FCNN Test Accuracy: {fcnn_test_acc}")
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - accuracy: 0.7492 - loss: 0.6775 - val_accuracy: 0.8302 - val_loss: 0.4494
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8536 - loss: 0.4038 - val_accuracy: 0.8487 - val_loss: 0.4379
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.8654 - loss: 0.3839 - val_accuracy: 0.8432 - val_loss: 0.4426
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 29s 17ms/step - accuracy: 0.8729 - loss: 0.3693 - val_accuracy: 0.8653 - val_loss: 0.4086
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 26s 15ms/step - accuracy: 0.8716 - loss: 0.3724 - val_accuracy: 0.8752 - val_loss: 0.3839
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 25s 15ms/step - accuracy: 0.8776 - loss: 0.3595 - val_accuracy: 0.8712 - val_loss: 0.3975
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - accuracy: 0.8766 - loss: 0.3688 - val_accuracy: 0.8697 - val_loss: 0.4646
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.8751 - loss: 0.3772 - val_accuracy: 0.8515 - val_loss: 0.4707
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8773 - loss: 0.3758 - val_accuracy: 0.8697 - val_loss: 0.4523
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8765 - loss: 0.3808 - val_accuracy: 0.8733 - val_loss: 0.5540
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8630 - loss: 0.5866
# FCNN Test Accuracy: 0.8610000014305115

# %% [markdown]
# **Training and Testing CNN Model**

# %%
cnn_model.compile(loss='categorical_crossentropy', optimizer=RMSprop(), metrics=['accuracy'])
cnn_history = cnn_model.fit(trainX, trainY, batch_size=32, validation_split=0.1, epochs=10)

cnn_test_loss, cnn_test_acc = cnn_model.evaluate(testX, testY)
print(f"CNN Test Accuracy: {cnn_test_acc}")
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 39s 21ms/step - accuracy: 0.7432 - loss: 0.6903 - val_accuracy: 0.8730 - val_loss: 0.3692
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 52s 31ms/step - accuracy: 0.8915 - loss: 0.2948 - val_accuracy: 0.8987 - val_loss: 0.2741
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 59s 35ms/step - accuracy: 0.9130 - loss: 0.2397 - val_accuracy: 0.9060 - val_loss: 0.2540
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 42s 25ms/step - accuracy: 0.9236 - loss: 0.2112 - val_accuracy: 0.9128 - val_loss: 0.2485
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 39s 23ms/step - accuracy: 0.9295 - loss: 0.1946 - val_accuracy: 0.9162 - val_loss: 0.2505
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 51s 30ms/step - accuracy: 0.9365 - loss: 0.1750 - val_accuracy: 0.9107 - val_loss: 0.2834
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 55s 33ms/step - accuracy: 0.9382 - loss: 0.1717 - val_accuracy: 0.9148 - val_loss: 0.2944
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 49s 29ms/step - accuracy: 0.9422 - loss: 0.1667 - val_accuracy: 0.9113 - val_loss: 0.3180
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9420 - loss: 0.1667 - val_accuracy: 0.9175 - val_loss: 0.3160
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 44s 26ms/step - accuracy: 0.9430 - loss: 0.1624 - val_accuracy: 0.9002 - val_loss: 0.5014
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8947 - loss: 0.6171
# CNN Test Accuracy: 0.8942000269889832

# %% [markdown]
# **Comparing Two Model**

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(fcnn_history.history['accuracy']) + 1)

plt.figure(figsize=(12,6))

plt.plot(epochs, fcnn_history.history['accuracy'], 'b-', label='FCNN Training Accuracy')
plt.plot(epochs, cnn_history.history['accuracy'], 'g-', label='CNN Training Accuracy')

plt.plot(epochs, fcnn_history.history['val_accuracy'], 'b--', label='FCNN Validation Accuracy')
plt.plot(epochs, cnn_history.history['val_accuracy'], 'g--', label='CNN Validation Accuracy')

plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
